# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
normal = pd.DataFrame({'rand':np.random.normal(0, 1, 100)})
plt.hist(normal['rand'], color='c')
plt.axvline(x=0)
plt.axvline(x=1, color='red')
plt.axvline(x=-1, color='red')
plt.show()

# %%
gumbel = pd.DataFrame({'rand':np.random.gumbel(0, 1, 100)})
plt.hist(gumbel['rand'])
plt.show()

# %%
chisquare = pd.DataFrame({'rand':np.random.chisquare(1,100)})
plt.hist(chisquare['rand'])
plt.show()

# %%
laplace = pd.DataFrame({'rand':np.random.laplace(0, 1, 100)})
plt.hist(laplace['rand'])
plt.show()

# %%
rawdata = pd.DataFrame(np.random.dirichlet((4, 5, 10), 100))
plt.hist(rawdata)
plt.show
# I played around with the 3 input numbers on this and got wildly different graphs 
# am rather confused as to what is happening.
# Out:
# <function matplotlib.pyplot.show>

# %%
wald = pd.DataFrame({'rand':np.random.wald(.5, 20, 100)})
plt.hist(wald['rand'])
plt.show()
