# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
normal = np.random.normal(0, 1, 100)
plt.hist(normal, color='c')
mean = np.mean(normal)
st_dev = np.std(normal)
plt.axvline(x=mean, color='red')
plt.axvline(x=(mean + st_dev), color='red', linestyle='--')
plt.axvline(x=(mean - st_dev), color='red', linestyle='--')
plt.show()
#The descriptive statistics of mean and standard deviation are as expected in this graph

# %%
gumbel = np.random.gumbel(0, 1, 100)
plt.hist(gumbel)
mean = np.mean(gumbel)
st_dev = np.std(gumbel)
plt.axvline(x=mean, color='red')
plt.axvline(x=(mean + st_dev), color='red', linestyle='--')
plt.axvline(x=(mean - st_dev), color='red', linestyle='--')
plt.show()

# %%
chisquare = np.random.chisquare(1,100)
plt.hist(chisquare)
mean = np.mean(chisquare)
st_dev = np.std(chisquare)
plt.axvline(x=mean, color='red')
plt.axvline(x=(mean + st_dev), color='red', linestyle='--')
plt.axvline(x=(mean - st_dev), color='red', linestyle='--')
plt.show()

# %%
laplace = np.random.laplace(0, 1, 100)
plt.hist(laplace)
mean = np.mean(laplace)
st_dev = np.std(laplace)
plt.axvline(x=mean, color='red')
plt.axvline(x=(mean + st_dev), color='red', linestyle='--')
plt.axvline(x=(mean - st_dev), color='red', linestyle='--')
plt.show()

# %%
dirichlet = np.random.dirichlet((4, 5, 10), 100)
plt.hist(dirichlet)
mean = np.mean(dirichlet)
st_dev = np.std(dirichlet)
plt.axvline(x=mean, color='red')
plt.axvline(x=(mean + st_dev), color='red', linestyle='--')
plt.axvline(x=(mean - st_dev), color='red', linestyle='--')
plt.show()
# I played around with the 3 input numbers on this and got wildly different graphs 
# and am rather confused as to what is happening.

# %%
wald = np.random.wald(.5, 20, 100)
plt.hist(wald)
mean = np.mean(wald)
st_dev = np.std(wald)
plt.axvline(x=mean, color='red')
plt.axvline(x=(mean + st_dev), color='red', linestyle='--')
plt.axvline(x=(mean - st_dev), color='red', linestyle='--')
plt.show()

# %%
#additionally
var1 = np.random.normal(5, .5, 100)
var2 = np.random.normal(10, 1, 100)
var3 = var1 + var2
plt.hist(var3)
mean = np.mean(var3)
st_dev = np.std(var3)
plt.axvline(x=mean, color='red')
plt.axvline(x=st_dev, color='red')
